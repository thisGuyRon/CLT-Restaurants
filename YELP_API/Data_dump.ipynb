# %%
import pandas as pd
import numpy as np

# %%
char = "Data/CharYelp2.csv"

# %%
char_pd = pd.read_csv(char)
char_pd.head(5)
# Out:
#                        id                             alias  \
# 0  yrUDeng1LrDvgyyjI5GiHA               pho-quynh-charlotte
# 1  PqcOSnCsJTT9Yd2xWKIMWw          la-shish-kabob-charlotte
# 2  LdhprCGxa0inFo5P812EIg         loft-and-cellar-charlotte
# 3  VH3WA7a-OVzFj2K_SP4BIw       the-kings-kitchen-charlotte
# 4  trAd97ig2agtkZl2cimOMQ  something-classic-cafe-charlotte
#
#                      name                                          image_url  \
# 0               Pho Quynh  https://s3-media4.fl.yelpcdn.com/bphoto/MnKklw...
# 1          La Shish Kabob  https://s3-media2.fl.yelpcdn.com/bphoto/Omf3DF...
# 2           Loft & Cellar  https://s3-media2.fl.yelpcdn.com/bphoto/dOSRTq...
# 3      The King's Kitchen  https://s3-media2.fl.yelpcdn.com/bphoto/wGKQhL...
# 4  Something Classic Cafe  https://s3-media2.fl.yelpcdn.com/bphoto/kSy_l4...
#
#   is_closed                                                url  review_count  \
# ...
